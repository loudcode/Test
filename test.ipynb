# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

os.chdir("C:\\Users\\user\Desktop\Test")

# %%
#Импорт датасета
AH = pd.read_csv('dataset_Facebook.txt', sep="\t", header = 0, index_col=False)
print('Размер датасета', AH.shape)
# Out:
# Размер датасета (500, 19)

# %%
#Описательная статистика
AH.describe(include='all')
# Out:
#         Page total likes   Type    Category  Post Month  Post Weekday  \
# count         500.000000    500  500.000000  500.000000    500.000000
# unique               NaN      4         NaN         NaN           NaN
# top                  NaN  Photo         NaN         NaN           NaN
# freq                 NaN    426         NaN         NaN           NaN
# mean       123194.176000    NaN    1.880000    7.038000      4.150000
# std         16272.813214    NaN    0.852675    3.307936      2.030701
# min         81370.000000    NaN    1.000000    1.000000      1.000000
# 25%        112676.000000    NaN    1.000000    4.000000      2.000000
# 50%        129600.000000    NaN    2.000000    7.000000      4.000000
# 75%        136393.000000    NaN    3.000000   10.000000      6.000000
# max        139441.000000    NaN    3.000000   12.000000      7.000000
#
#          Post Hour        Paid  Lifetime Post Total Reach  \
# count   500.000000  499.000000                  500.00000
# ...

# %%
#среднее
AH.mean()
# Out:
# Page total likes                                                       123194.176000
# Category                                                                    1.880000
# Post Month                                                                  7.038000
# Post Weekday                                                                4.150000
# Post Hour                                                                   7.840000
# Paid                                                                        0.278557
# Lifetime Post Total Reach                                               13903.360000
# Lifetime Post Total Impressions                                         29585.948000
# Lifetime Engaged Users                                                    920.344000
# Lifetime Post Consumers                                                   798.772000
# Lifetime Post Consumptions                                               1415.130000
# ...

# %%
#минимальное значение
AH.min()
# Out:
# Page total likes                                                       81370
# Type                                                                    Link
# Category                                                                   1
# Post Month                                                                 1
# Post Weekday                                                               1
# Post Hour                                                                  1
# Paid                                                                       0
# Lifetime Post Total Reach                                                238
# Lifetime Post Total Impressions                                          570
# Lifetime Engaged Users                                                     9
# Lifetime Post Consumers                                                    9
# Lifetime Post Consumptions                                                 9
# ...

# %%
AH['Type'].min()
# Out:
# 'Link'

# %%
#максимальное значение
AH.max()
# Out:
# Page total likes                                                        139441
# Type                                                                     Video
# Category                                                                     3
# Post Month                                                                  12
# Post Weekday                                                                 7
# Post Hour                                                                   23
# Paid                                                                         1
# Lifetime Post Total Reach                                               180480
# Lifetime Post Total Impressions                                        1110282
# Lifetime Engaged Users                                                   11452
# Lifetime Post Consumers                                                  11328
# Lifetime Post Consumptions                                               19779
# ...

# %%
AH['Type'].max()
# Out:
# 'Video'

# %%
#медиана
AH.median()
# Out:
# Page total likes                                                       129600.0
# Category                                                                    2.0
# Post Month                                                                  7.0
# Post Weekday                                                                4.0
# Post Hour                                                                   9.0
# Paid                                                                        0.0
# Lifetime Post Total Reach                                                5281.0
# Lifetime Post Total Impressions                                          9051.0
# Lifetime Engaged Users                                                    625.5
# Lifetime Post Consumers                                                   551.5
# Lifetime Post Consumptions                                                851.0
# Lifetime Post Impressions by people who have liked your Page             6255.5
# ...

# %%
#мода
AH.mode()
# Out:
#     Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0           136393.0  Photo       1.0        10.0           7.0        3.0
# 1                NaN    NaN       NaN         NaN           NaN        NaN
# 2                NaN    NaN       NaN         NaN           NaN        NaN
# 3                NaN    NaN       NaN         NaN           NaN        NaN
# 4                NaN    NaN       NaN         NaN           NaN        NaN
# 5                NaN    NaN       NaN         NaN           NaN        NaN
# 6                NaN    NaN       NaN         NaN           NaN        NaN
# 7                NaN    NaN       NaN         NaN           NaN        NaN
# 8                NaN    NaN       NaN         NaN           NaN        NaN
# 9                NaN    NaN       NaN         NaN           NaN        NaN
# 10               NaN    NaN       NaN         NaN           NaN        NaN
# ...

# %%
AH['Type'].mode()
# Out:
# 0    Photo
# dtype: object

# %%
pd.Series.max(AH, level=0)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
#самый популярный объект в выборке, объяснить почему
AH.nlargest(1, 'Total Interactions')
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 244                    8072                     4010
#
#      Lifetime Post Consumptions  \
# 244                        6242
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 244                                             108752
#
#      Lifetime Post reach by people who like your Page  \
# 244                                             51456
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 244                                               3316
#
#      comment    like  share  Total Interactions
# 244      372  5172.0  790.0                6334

# %%
#Фото наиболее удобный обмен визуальной информацией.
#Фото может рассказать о человека, показать где он был, чем занимался.
#Большое количество фотографии обуславливается популярности селфи, мемов и прочего image контента.
AH['Type'].value_counts().plot.pie()
